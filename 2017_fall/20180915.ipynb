# %% [markdown]
# # this is your first class note:
#
# here is a quik check-up list:
#
# 1. make sure you register trello.com and inform me your registration email so that I can add you to our class.
#
# 2. make sure you have anaconda for python3 installed on your computer:
#
# 3. start learning python outside this class:
# https://www.codecademy.com/learn/learn-python?composer_curriculum_redirect=python
#
# 4. mark my contact info:
# sun, qiang
# qqss88@gmail.com
# 240-406-4949
# wechat: sunshine16da8(we do have a wechat group)
#
# 5. let me know if you have any questions/suggestions.
#
# Thanks for your attention and trust:-)

# %% [markdown]
# # you can do some math with math with python:
# link1:
# https://docs.python.org/2/library/math.html
# link2:
# https://pythonprogramming.net/math-basics-python-3-beginner-tutorial/

# %%
1999+67
# Out:
# 2066

# %%
3**3
# Out:
# 27

# %%
# a little complicatd one
for m in range(1,11):
    print(m*m)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
# this week video on computer science
from IPython.lib.display import YouTubeVideo
YouTubeVideo('OAx_6-wdslM')

# %%
# try to run this and see what this piece of code is doing:

print('waht is your name?')
_name = input()
print('what is your email?')
_email = input()
print('what is your phone number?')
_phone = input()
print('what is your favoriate game?')
_game = input()

# let us make a meesage for print out
_message = """
my name is {},
my favorite game is {}
""".format(_name, _game)

print(_message)
# Out:
# waht is your name?
# George Xie
# what is your email?
# xiemaozhou@Gmail.com
# what is your phone number?
# N/A
# what is your favoriate game?
# N/A
#
# my name is George Xie,
# my favorite game is N/A
