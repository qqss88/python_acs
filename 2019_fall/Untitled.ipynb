# %%
print('hello, python!')
# Out:
# hello, python!

# %% [markdown]
# # TODO List
# 1. watch youtube video:
#
#
# 2. review our first data structure: List
#
# https://www.tutorialspoint.com/python/python_lists.htm
#
# 3. for looping:
# https://realpython.com/python-for-loop/#targetText=The%20Python%20for%20Loop,-Of%20the%20loop&targetText=The,each%20time%20through%20the%20loop.
#
# 4. review 3 projects:
#     - add_up_numbers
#     - check_prime_number
#     - pick_a_name
#
# 4. lab session
#
#
# # HW
# 1. play with python list:
# https://www.tutorialspoint.com/python/python_lists.htm
#
# 2. watch this youtube video:
# https://www.youtube.com/watch?v=ohCDWZgNIU0
#
# 3. project:
# find out all the numbers that:
#     - can be divided both by 3 and 5
#     - in the range of 1 to 1000,000
#     - add them up
#
# 4. check out this turtle code - do you understand what the code does?
# https://trinket.io/python/88dd6c94d1
#
# 5. checkout the trello lecture notes
#
#
# Questions: trello? anaconda? other?

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('xnyFYiK2rSY')

# %%
# random pick up a name NOT starting with A, and NOT Ivy
students = ['Ivy',
 'Alan',
 'Mary',
 'Isabel',
 'Alex',
 'Dennis',
 'Melissa',
 'keyon',
 'AlanS']

def pick_name(names):
    pass

# %%
import inspect
import os


print (inspect.getsource(inspect))
# Out:
# """Get useful information from live Python objects.
#
# This module encapsulates the interface provided by the internal special
# attributes (co_*, im_*, tb_*, etc.) in a friendlier fashion.
# It also provides some help for examining source code and class layout.
#
# Here are some of the useful functions provided by this module:
#
#     ismodule(), isclass(), ismethod(), isfunction(), isgeneratorfunction(),
#         isgenerator(), istraceback(), isframe(), iscode(), isbuiltin(),
#         isroutine() - check object types
#     getmembers() - get members of an object that satisfy a given condition
#
#     getfile(), getsourcefile(), getsource() - find an object's source code
#     getdoc(), getcomments() - get documentation on an object
#     getmodule() - determine the module that an object came from
#     getclasstree() - arrange classes so as to represent their hierarchy
#
#     getargvalues(), getcallargs() - get info about function arguments
# ...
